# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.tight_layout()
import matplotlib 
font = {'family' : 'DejaVu Sans',  # hoặc 'Arial', 'Times New Roman'
        'weight' : 'normal',
        'size'   : 20}
matplotlib.rc('font', **font)

# %%
df_remove_spare_columns = pd.read_csv("../data/data_remove_spare_columns.csv")

# %%
num_instances = df_remove_spare_columns[df_remove_spare_columns.columns[0]].count()

# %%
df_remove_spare_columns['Species'].unique()
# Out:
# array(['Adelie Penguin (Pygoscelis adeliae)',
#        'Chinstrap penguin (Pygoscelis antarctica)',
#        'Gentoo penguin (Pygoscelis papua)'], dtype=object)

# %%
# Species percentage
species_list = list()
species_list.append((df_remove_spare_columns['Species'].values ==
                     'Adelie Penguin (Pygoscelis adeliae)').sum() / num_instances)
species_list.append((df_remove_spare_columns['Species'].values ==
                     'Chinstrap penguin (Pygoscelis antarctica)').sum() / num_instances)
species_list.append((df_remove_spare_columns['Species'].values ==
                     'Gentoo penguin (Pygoscelis papua)').sum() / num_instances)
plt.pie(species_list, labels = ['Adelie', 'Chinstrap', 'Gentoo'], 
        autopct='%1.1f%%', startangle=90, colors = ['green', 'orange', 'pink'])

plt.savefig('../pics/Visualization/Species_plot.svg', bbox_inches='tight')
plt.savefig('../pics/Visualization/Species_plot.pdf', bbox_inches='tight')

# %%
from sklearn.datasets import load_iris
from numpy import array
from pandas import DataFrame
from pandas.plotting import scatter_matrix

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 20}

a = pd.read_csv('../data/data_remove_outliers.csv')
b = a[['Species']].copy().values
a = a.drop(['Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Species', 'Sex'], axis = 1).values
iris = load_iris()
df = DataFrame(a, columns=['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)'])
# Adelie, Chinstrap, Gentoo
colors=array(151*['red']+68*['g']+123*['orange'])
scatter_matrix(df, alpha=0.2, figsize=(20,20), color = colors, marker = 'o')
plt.savefig('../pics/Visualization/scatter_plot.svg', bbox_inches='tight')
plt.savefig('../pics/Visualization/scatter_plot.pdf', bbox_inches='tight')

# %%
a = pd.read_csv('../data/data_remove_outliers.csv')
a.isna().sum()
# Out:
# Species                 0
# Culmen Length (mm)      0
# Culmen Depth (mm)       0
# Flipper Length (mm)     0
# Body Mass (g)           0
# Sex                     8
# Delta 15 N (o/oo)      12
# Delta 13 C (o/oo)      11
# dtype: int64
